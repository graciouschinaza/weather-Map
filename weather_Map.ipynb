# %% [markdown]
# <a href="https://colab.research.google.com/github/graciouschinaza/weather-Map/blob/main/weather_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
import requests
import pandas as pd

api_key = "8772f358479def3944d766d2a6c350e4"

cities = ["Aba", "Onitsha", "Warri"]

weather_data = []

for city in cities:
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        weather_data.append({
            "City": data["name"],
            "Temperature": data["main"]["temp"],
            "Humidity": data["main"]["humidity"],
            "Weather Condition": data["weather"][0]["description"],
            "Wind Speed": data["wind"]["speed"],
            "Date and Time": pd.to_datetime(data["dt"], unit="s")
        })
    else:
        print(f"Could not retrieve data for {city}")

weather_data
# Out:
# [{'City': 'Aba',
#   'Temperature': 24.98,
#   'Humidity': 88,
#   'Weather Condition': 'light rain',
#   'Wind Speed': 2.32,
#   'Date and Time': Timestamp('2026-08-17 16:17:29')},
#  {'City': 'Onitsha',
#   'Temperature': 25.07,
#   'Humidity': 91,
#   'Weather Condition': 'moderate rain',
#   'Wind Speed': 2.14,
#   'Date and Time': Timestamp('2026-08-17 16:17:29')},
#  {'City': 'Warri',
#   'Temperature': 27.81,
#   'Humidity': 71,
#   'Weather Condition': 'light rain',
#   'Wind Speed': 3.14,
#   'Date and Time': Timestamp('2026-08-17 16:17:29')}]

# %%
df = pd.DataFrame(weather_data)

df
# Out:
#       City  Temperature  Humidity Weather Condition  Wind Speed  \
# 0      Aba        24.98        88        light rain        2.32
# 1  Onitsha        25.07        91     moderate rain        2.14
# 2    Warri        27.81        71        light rain        3.14
#
#         Date and Time
# 0 2026-08-17 16:17:29
# 1 2026-08-17 16:17:29
# 2 2026-08-17 16:17:29

# %%
df.shape
# Out:
# (3, 6)

# %%
df.columns
# Out:
# Index(['City', 'Temperature', 'Humidity', 'Weather Condition', 'Wind Speed',
#        'Date and Time'],
#       dtype='object')

# %%
df.dtypes
# Out:
# City                         object
# Temperature                 float64
# Humidity                      int64
# Weather Condition            object
# Wind Speed                  float64
# Date and Time        datetime64[ns]
# dtype: object

# %%
df.isnull().sum()
# Out:
# City                 0
# Temperature          0
# Humidity             0
# Weather Condition    0
# Wind Speed           0
# Date and Time        0
# dtype: int64

# %% [markdown]
# no missing values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# no duplicate rows

# %%
df["Date and Time"] = pd.to_datetime(df["Date and Time"])

# %%
df = df.rename(columns={
    "City": "City",
    "Temperature": "Temperature_C",
    "Humidity": "Humidity_Percent",
    "Weather Condition": "Weather_Condition",
    "Wind Speed": "Wind_Speed",
    "Date and Time": "Date_Time"
})

# %%
df.head()
# Out:
#       City  Temperature_C  Humidity_Percent Weather_Condition  Wind_Speed  \
# 0      Aba          24.98                88        light rain        2.32
# 1  Onitsha          25.07                91     moderate rain        2.14
# 2    Warri          27.81                71        light rain        3.14
#
#             Date_Time
# 0 2026-08-17 16:17:29
# 1 2026-08-17 16:17:29
# 2 2026-08-17 16:17:29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3 non-null      object
#  1   Temperature_C      3 non-null      float64
#  2   Humidity_Percent   3 non-null      int64
#  3   Weather_Condition  3 non-null      object
#  4   Wind_Speed         3 non-null      float64
#  5   Date_Time          3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df
# Out:
#       City  Temperature_C  Humidity_Percent Weather_Condition  Wind_Speed  \
# 0      Aba          24.98                88        light rain        2.32
# 1  Onitsha          25.07                91     moderate rain        2.14
# 2    Warri          27.81                71        light rain        3.14
#
#             Date_Time
# 0 2026-08-17 16:17:29
# 1 2026-08-17 16:17:29
# 2 2026-08-17 16:17:29

# %%
df.to_csv("weather_data_cleaned.csv",index=False)

# %%
import os
os.path.exists("weather_data_cleaned.csv")
# Out:
# True

# %%
check_data=pd.read_csv("weather_data_cleaned.csv")
check_data
# Out:
#       City  Temperature_C  Humidity_Percent Weather_Condition  Wind_Speed  \
# 0      Aba          24.98                88        light rain        2.32
# 1  Onitsha          25.07                91     moderate rain        2.14
# 2    Warri          27.81                71        light rain        3.14
#
#              Date_Time
# 0  2026-08-17 16:17:29
# 1  2026-08-17 16:17:29
# 2  2026-08-17 16:17:29

# %%
from google.colab import files
files.download("weather_data_cleaned.csv")

# %%
df
# Out:
#       City  Temperature_C  Humidity_Percent Weather_Condition  Wind_Speed  \
# 0      Aba          24.98                88        light rain        2.32
# 1  Onitsha          25.07                91     moderate rain        2.14
# 2    Warri          27.81                71        light rain        3.14
#
#             Date_Time
# 0 2026-08-17 16:17:29
# 1 2026-08-17 16:17:29
# 2 2026-08-17 16:17:29

# %%
temperature_comparison=df[["City","Temperature_C"]]
temperature_comparison
# Out:
#       City  Temperature_C
# 0      Aba          24.98
# 1  Onitsha          25.07
# 2    Warri          27.81

# %% [markdown]
# Temperature Comparison

# %%
hottest_city = df.loc[df["Temperature_C"].idxmax()]

print("Hottest City:", hottest_city["City"])
print("Temperature:", hottest_city["Temperature_C"], "°C")
# Out:
# Hottest City: Warri
# Temperature: 27.81 °C

# %% [markdown]
# Warri is the hottest city with the Temperature as 26.87 °C

# %%
coolest_city = df.loc[df["Temperature_C"].idxmin()]

print("Coolest City:", coolest_city["City"])
print("Temperature:", coolest_city["Temperature_C"], "°C")
# Out:
# Coolest City: Aba
# Temperature: 24.98 °C

# %% [markdown]
# Aba is the coolest city with its Temperature as 25.89 °C

# %%
highest_humidity = df.loc[df["Humidity_Percent"].idxmax()]

print("City with Highest Humidity:", highest_humidity["City"])
print("Humidity:", highest_humidity["Humidity_Percent"], "%")
# Out:
# City with Highest Humidity: Onitsha
# Humidity: 91 %

# %% [markdown]
# Onitsha is the city with the hightest humidity among the 3 cities

# %%
weather_comparison = df[["City", "Weather_Condition"]]

weather_comparison
# Out:
#       City Weather_Condition
# 0      Aba        light rain
# 1  Onitsha     moderate rain
# 2    Warri        light rain

# %%
hottest = df.loc[df["Temperature_C"].idxmax()]
coolest = df.loc[df["Temperature_C"].idxmin()]
most_humid = df.loc[df["Humidity_Percent"].idxmax()]

print("WEATHER ANALYSIS SUMMARY")
print("------------------------")
print(f"Hottest city: {hottest['City']} ({hottest['Temperature_C']} °C)")
print(f"Coolest city: {coolest['City']} ({coolest['Temperature_C']} °C)")
print(f"Highest humidity: {most_humid['City']} ({most_humid['Humidity_Percent']}%)")
print("\nWeather conditions:")
print(df[["City", "Weather_Condition"]].to_string(index=False))
# Out:
# WEATHER ANALYSIS SUMMARY
# ------------------------
# Hottest city: Warri (27.81 °C)
# Coolest city: Aba (24.98 °C)
# Highest humidity: Onitsha (91%)
#
# Weather conditions:
#    City Weather_Condition
#     Aba        light rain
# Onitsha     moderate rain
#   Warri        light rain
